# %%
import numpy as np

# %%
import csv

# %%
data = []

# %%
with open(r"C:\Users\HP\Desktop\Data-LB\New folder\MER_T07_02A-2020-02-03.csv",'r') as csvfile:
    filereader = csv.reader(csvfile,delimiter=',')
    for row in filereader:
        data.append(row)

# %%
data
# Out:
# [['MSN', 'YYYYMM', 'Value', 'Column_Order', 'Description', 'Unit'],
#  ['CLETPUS',
#   '194913',
#   '135451.32',
#   '1',
#   'Electricity Net Generation From Coal, All Sectors',
#   'Million Kilowatthours'],
#  ['CLETPUS',
#   '195013',
#   '154519.994',
#   '1',
#   'Electricity Net Generation From Coal, All Sectors',
#   'Million Kilowatthours'],
#  ['CLETPUS',
#   '195113',
#   '185203.657',
#   '1',
#   'Electricity Net Generation From Coal, All Sectors',
#   'Million Kilowatthours'],
#  ['CLETPUS',
#   '195213',
#   '195436.666',
#   '1',
#   'Electricity Net Generation From Coal, All Sectors',
#   'Million Kilowatthours'],
#  ['CLETPUS',
#   '195313',
#   '218846.325',
#   '1',
#   'Electricity Net Generation From Coal, All Sectors',
#   'Million Kilowatthours'],
#  ['CLETPUS',
#   '195413',
#   '239145.966',
#   '1',
#   'Electricity Net Generation From Coal, All Sectors',
#   'Million Kilowatthours'],
#  ['CLETPUS',
#   '195513',
#   '301362.698',
#   '1',
# ...

# %%
data = np.array(data)

# %%
data
# Out:
# array([['MSN', 'YYYYMM', 'Value', 'Column_Order', 'Description', 'Unit'],
#        ['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ...,
#        ['ELETPUS', '201908', '401363.186', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201909', '359300.603', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201910', '321921.812', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours']], dtype='<U80')

# %% [markdown]
# # 1. Explore the important attributes like dimension,shape, data type etc, of the array formed above

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (8217, 6)

# %%
data.dtype.type
# Out:
# numpy.str_

# %% [markdown]
# # 2. Print the data contained in the first 10 rows of the 4th column.

# %%
data[0:10]
# Out:
# array([['MSN', 'YYYYMM', 'Value', 'Column_Order', 'Description', 'Unit'],
#        ['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195113', '185203.657', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195213', '195436.666', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195313', '218846.325', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195413', '239145.966', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
# ...

# %%
data[-5:]
# Out:
# array([['ELETPUS', '201906', '351342.905', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201907', '411583.828', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201908', '401363.186', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201909', '359300.603', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201910', '321921.812', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours']], dtype='<U80')

# %%
np.vstack((data[0:5],data[-5:]))
# Out:
# array([['MSN', 'YYYYMM', 'Value', 'Column_Order', 'Description', 'Unit'],
#        ['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195113', '185203.657', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195213', '195436.666', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201906', '351342.905', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201907', '411583.828', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
# ...

# %%
##Print the data contained in the first 10 rows of the 4th column
data[0:10,3:4]
# Out:
# array([['Column_Order'],
#        ['1'],
#        ['1'],
#        ['1'],
#        ['1'],
#        ['1'],
#        ['1'],
#        ['1'],
#        ['1'],
#        ['1']], dtype='<U80')

# %% [markdown]
# # 3. Which row serves as the headers/titles for all the columns.

# %%
#first row
data[0:1]
# Out:
# array([['MSN', 'YYYYMM', 'Value', 'Column_Order', 'Description', 'Unit']],
#       dtype='<U80')

# %% [markdown]
# # 4. Print the data contained in column 2 and 3 from row 1 till row 20

# %%
data[0:20,1:3]
# Out:
# array([['YYYYMM', 'Value'],
#        ['194913', '135451.32'],
#        ['195013', '154519.994'],
#        ['195113', '185203.657'],
#        ['195213', '195436.666'],
#        ['195313', '218846.325'],
#        ['195413', '239145.966'],
#        ['195513', '301362.698'],
#        ['195613', '338503.484'],
#        ['195713', '346386.207'],
#        ['195813', '344365.781'],
#        ['195913', '378424.21'],
#        ['196013', '403067.357'],
#        ['196113', '421870.669'],
#        ['196213', '450249.238'],
#        ['196313', '493926.719'],
#        ['196413', '526230.019'],
#        ['196513', '570925.951'],
#        ['196613', '613474.8'],
#        ['196713', '630483.363']], dtype='<U80')

# %% [markdown]
# # 5. Print the data present in only the first three and the last three rows of all the columns in a single output.

# %%
np.vstack((data[0:3],data[-3:]))
# Out:
# array([['MSN', 'YYYYMM', 'Value', 'Column_Order', 'Description', 'Unit'],
#        ['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201908', '401363.186', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201909', '359300.603', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201910', '321921.812', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours']], dtype='<U80')

# %% [markdown]
# # 6. Sort the data on the basis of net amount of electricity generated irrespective of the source

# %%
value = data[1:,2]

# %%
cndn_of_slcn = (data[:,2]!="Not Available")
cndn_of_slcn.shape
# Out:
# (8217,)

# %%
a = data[cndn_of_slcn]
a
# Out:
# array([['MSN', 'YYYYMM', 'Value', 'Column_Order', 'Description', 'Unit'],
#        ['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ...,
#        ['ELETPUS', '201908', '401363.186', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201909', '359300.603', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201910', '321921.812', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours']], dtype='<U80')

# %%
a.shape
# Out:
# (7387, 6)

# %%
e = a[1:,2].astype(float)
e
# Out:
# array([135451.32 , 154519.994, 185203.657, ..., 401363.186, 359300.603,
#        321921.812])

# %%
e = np.sort(e)
e
# Out:
# array([  -8823.445,   -8742.928,   -8535.065, ..., 4125059.9  ,
#        4156744.724, 4174397.655])

# %% [markdown]
# # 7. Find the total amount of electricity generated using coal and nuclear between 1949-1990.( In this dataset, rows containing monthly data express date in the format 'YYYYMM'. Rows containing annual data express the date in the format 'YYYY13'.)

# %%
data
# Out:
# array([['MSN', 'YYYYMM', 'Value', 'Column_Order', 'Description', 'Unit'],
#        ['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ...,
#        ['ELETPUS', '201908', '401363.186', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201909', '359300.603', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201910', '321921.812', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours']], dtype='<U80')

# %%
b = a[1:]

# %%
time = a[1:,1]

# %%
time = time.astype(int)

# %%
cond_time = np.mod(time,100)==13
cond_time
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
cond_time.shape
# Out:
# (7386,)

# %%
t = b[cond_time]
t
# Out:
# array([['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195113', '185203.657', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ...,
#        ['ELETPUS', '201613', '4076674.984', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201713', '4034270.522', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201813', '4174397.655', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
# ...

# %%
t.shape
# Out:
# (728, 6)

# %%
cond_timelimit = t[0:,1].astype(int)<=199013

# %%
t = t[cond_timelimit]
t
# Out:
# array([['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195113', '185203.657', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ...,
#        ['ELETPUS', '198813', '2707411.178', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '198913', '2967146.087', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '199013', '3037827.337', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
# ...

# %%
t.shape
# Out:
# (364, 6)

# %%
source_cndn = t[:,4]=='Electricity Net Generation From Coal, All Sectors'

# %%
energy_coal = t[source_cndn]
energy_coal.shape
# Out:
# (42, 6)

# %%
source_cndn_nuc = t[:,4]=='Electricity Net Generation From Nuclear Electric Power, All Sectors'

# %%
energy_nuc = t[source_cndn_nuc]
energy_nuc.shape
# Out:
# (42, 6)

# %%
final_energy = np.vstack((energy_coal,energy_nuc))
final_energy
# Out:
# array([['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195113', '185203.657', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195213', '195436.666', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195313', '218846.325', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195413', '239145.966', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195513', '301362.698', '1',
# ...

# %%
np.sum(final_energy[:,2].astype(float))
# Out:
# 37990978.569000006

# %% [markdown]
# # 8. Print all the unique sources of Energy generation present in the dataset.

# %%
np.unique(data[:,4:5])
# Out:
# array(['Description', 'Electricity Net Generation From Coal, All Sectors',
#        'Electricity Net Generation From Conventional Hydroelectric Power, All Sectors',
#        'Electricity Net Generation From Geothermal, All Sectors',
#        'Electricity Net Generation From Hydroelectric Pumped Storage, All Sectors',
#        'Electricity Net Generation From Natural Gas, All Sectors',
#        'Electricity Net Generation From Nuclear Electric Power, All Sectors',
#        'Electricity Net Generation From Other Gases, All Sectors',
#        'Electricity Net Generation From Petroleum, All Sectors',
#        'Electricity Net Generation From Solar, All Sectors',
#        'Electricity Net Generation From Waste, All Sectors',
#        'Electricity Net Generation From Wind, All Sectors',
#        'Electricity Net Generation From Wood, All Sectors',
#        'Electricity Net Generation Total (including from sources not shown), All Sectors'],
#       dtype='<U80')

# %% [markdown]
# # 9. Print all the details(annual) where the energy source is Wind Energy. Use the concept of masking to filter the data.

# %%
energy = a[1:]
energy
# Out:
# array([['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195113', '185203.657', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ...,
#        ['ELETPUS', '201908', '401363.186', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201909', '359300.603', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201910', '321921.812', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
# ...

# %%
e_1 = energy[:,1].astype(int)
e_1
# Out:
# array([194913, 195013, 195113, ..., 201908, 201909, 201910])

# %%
cond_time = np.mod(e_1,100)==13
cond_time
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
e_2 = energy[cond_time]
e_2
# Out:
# array([['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195113', '185203.657', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ...,
#        ['ELETPUS', '201613', '4076674.984', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201713', '4034270.522', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201813', '4174397.655', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
# ...

# %%
cond_wind = e_2[:,4]=='Electricity Net Generation From Wind, All Sectors'

# %%
annual_detail = e_2[cond_wind]
annual_detail.shape
# Out:
# (36, 6)

# %%
annual_detail
# Out:
# array([['WYETPUS', '198313', '2.668', '12',
#         'Electricity Net Generation From Wind, All Sectors',
#         'Million Kilowatthours'],
#        ['WYETPUS', '198413', '6.49', '12',
#         'Electricity Net Generation From Wind, All Sectors',
#         'Million Kilowatthours'],
#        ['WYETPUS', '198513', '5.762', '12',
#         'Electricity Net Generation From Wind, All Sectors',
#         'Million Kilowatthours'],
#        ['WYETPUS', '198613', '4.189', '12',
#         'Electricity Net Generation From Wind, All Sectors',
#         'Million Kilowatthours'],
#        ['WYETPUS', '198713', '3.541', '12',
#         'Electricity Net Generation From Wind, All Sectors',
#         'Million Kilowatthours'],
#        ['WYETPUS', '198813', '0.871', '12',
#         'Electricity Net Generation From Wind, All Sectors',
#         'Million Kilowatthours'],
#        ['WYETPUS', '198913', '2112.043', '12',
#         'Electricity Net Generation From Wind, All Sectors',
# ...

# %% [markdown]
# # 10. Print the Total Energy generated in the USA till date

# %%
totatl_energy = a[1:,2]

# %%
totatl_energy.shape
# Out:
# (7386,)

# %%
np.sum(totatl_energy.astype(float))
# Out:
# 642969289.517

# %% [markdown]
# # 11. Print the average annual energy generated from wind in the USA and also the standard deviation present in the energy generation.

# %%
wind_energy = annual_detail
wind_energy.shape
# Out:
# (36, 6)

# %%
np.sum(wind_energy[:,2].astype(float))
# Out:
# 1940339.685

# %%
avg_wind_energy = np.mean(wind_energy[:,2].astype(float))
avg_wind_energy
# Out:
# 53898.324583333335

# %%
##standard deviation
np.std(wind_energy[:,2].astype(float))
# Out:
# 81322.74833843806

# %% [markdown]
# # 12. What and when was the maximum annual energy generated?

# %%
energy
# Out:
# array([['CLETPUS', '194913', '135451.32', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195013', '154519.994', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ['CLETPUS', '195113', '185203.657', '1',
#         'Electricity Net Generation From Coal, All Sectors',
#         'Million Kilowatthours'],
#        ...,
#        ['ELETPUS', '201908', '401363.186', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201909', '359300.603', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
#         'Million Kilowatthours'],
#        ['ELETPUS', '201910', '321921.812', '13',
#         'Electricity Net Generation Total (including from sources not shown), All Sectors',
# ...

# %%
cond_max = np.argmax(energy[:,2].astype(float))
cond_max
# Out:
# 7375

# %%
max_energy_date = energy[cond_max]
max_energy_date[1]
# Out:
# '201813'

# %%
max_energy = np.max(energy[:,2].astype(float))
max_energy
# Out:
# 4174397.655
